# %%
import requests as rq

# %%
url = "https://www.google.com/url?sa=i&url=https%3A%2F%2Fnews.sky.com%2Fstory%2Frevealed-study-finds-how-pandas-gain-weight-on-a-bamboo-diet-12519252&psig=AOvVaw0AhqoRaa-XeG9UHELLa-_n&ust=1644833618921000&source=images&cd=vfe&ved=0CAsQjRxqFwoTCMDaqvK4_PUCFQAAAAAdAAAAABAD"

res=rq.get(url)

# %%
res.status_code
# Out:
# 200

# %%
f = open("panda.jpg", "wb")

f.write(res.content)
f.close()

# %%
f
# Out:
# <_io.BufferedWriter name='panda.jpg'>

# %%
from bs4 import BeautifulSoup

# %%
url = "https://www.goodreads.com/quotes/tag/{}"

# %%
url.format("love")
# Out:
# 'https://www.goodreads.com/quotes/tag/love'

# %%
res=rq.get(url)

# %%
res.text
# Out:
# '<!DOCTYPE html>\n<html class="desktop withSiteHeaderTopFullImage\n">\n<head>\n  <title>Popular Quotes</title>\n\n<meta content="Popular quotes from Goodreads members. Oscar Wilde: ‘Be yourself; everyone else is already taken.’, Marilyn Monroe: ‘I\'m selfish, impatient and a little ..." name=\'description\'>\n<meta content=\'telephone=no\' name=\'format-detection\'>\n<link href=\'https://www.goodreads.com/quotes\' rel=\'canonical\'>\n\n\n\n  \n  <!-- * Copied from https://info.analytics.a2z.com/#/docs/data_collection/csa/onboard */ -->\n<script>\n  //<![CDATA[\n    !function(){function n(n,t){var r=i(n);return t&&(r=r("instance",t)),r}var r=[],c=0,i=function(t){return function(){var n=c++;return r.push([t,[].slice.call(arguments,0),n,{time:Date.now()}]),i(n)}};n._s=r,this.csa=n}();\n    \n    if (window.csa) {\n      window.csa("Config", {\n        "Application": "GoodreadsMonolith",\n        "Events.SushiEndpoint": "https://unagi.amazon.com/1/events/com.amazon.csm.csa.prod",\n      
# ...

# %%
soup=BeautifulSoup(res.text)

# %%
soup.title
# Out:
# <title>Popular Quotes</title>

# %%
soup.p
# Out:
# <p>Welcome back. Just a moment while we sign you in to your Goodreads account.</p>

# %%
soup.like

# %%
links=soup.find_all("a")

# %%
dir(links[0])
# Out:
# ['DEFAULT_INTERESTING_STRING_TYPES',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_find_all',
#  '_find_one',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_should_pretty_print',
#  'append',
#  'attrs',
#  'can_be_empty_element',
#  'cdata_list_attributes',
#  'childGenerator',
#  'children',
#  'clear',
#  'contents',
#  'decode',
#  'decode_contents',
#  'decompose',
#  'decomposed',
# ...
